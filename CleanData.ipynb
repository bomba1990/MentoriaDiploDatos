# %% [markdown]
# Este archivo es para limpiar la información de entrada y generar un archivo limpio.

# %%
import pandas as pd

# %%
ds = pd.read_csv('input/DatasetPobCR_Train-A&V.csv', sep='\t', index_col = 0)
ds.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_279628684  190000.0       0      3       0     1       1     0    NaN
# 1  ID_f29eb3ddd  135000.0       0      4       0     1       1     1    1.0
# 2  ID_68de51c94       NaN       0      8       0     1       1     0    NaN
# 3  ID_d671db89c  180000.0       0      5       0     1       1     1    1.0
# 4  ID_d56d6f5f5  180000.0       0      5       0     1       1     1    1.0
#
#    r4h1  ...  TipoSanitario  EnergiaCocina  EliminacionBasura  EstadoPared  \
# 0     0  ...     sanitario2  energcocinar3          elimbasu1      epared2
# 1     0  ...     sanitario2  energcocinar2          elimbasu1      epared2
# 2     0  ...     sanitario2  energcocinar2          elimbasu1      epared2
# 3     0  ...     sanitario2  energcocinar2          elimbasu1      epared3
# 4     0  ...     sanitario2  energcocinar2          elimbasu1      epared3
#
# ...

# %%
ds[ds.v2a1 == 0]
# Out:
#                 Id  v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 399   ID_fc41f70bb   0.0       0      5       0     1       1     0    NaN
# 400   ID_3ead7d433   0.0       0      5       0     1       1     0    NaN
# 401   ID_e1c816a53   0.0       0      5       0     1       1     0    NaN
# 1070  ID_75f7cca97   0.0       0      4       0     1       1     0    NaN
# 1071  ID_5a4e9b989   0.0       0      4       0     1       1     0    NaN
# 1072  ID_2577568e4   0.0       0      4       0     1       1     0    NaN
# 4056  ID_1335572c3   0.0       0      6       0     1       1     0    NaN
# 4057  ID_607c142db   0.0       0      6       0     1       1     0    NaN
# 4058  ID_b5706b793   0.0       0      6       0     1       1     0    NaN
# 4059  ID_c6fbf9a17   0.0       0      6       0     1       1     0    NaN
# 4060  ID_27483b473   0.0       0      6       0     1       1     0    NaN
# ...

# %%
ds.to_csv("input/dataset_clean.csv")
